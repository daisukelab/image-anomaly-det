# %%
from dlcliche.notebook import *
from dlcliche.utils import *
sys.path.append('..')
import img_hash
from utils import *

dataroot = '/data/mvtec_ad/original'

params = EasyDict()
params.suffix = '.png'
params.project = 'mvtecad_phash16'
params.work_folder = 'tmp'

params.max_fpr = 0.1
params.min_tpr = 1.0
params.sigma_k = 2.0

params.data = {}
params.data.pre_crop_rect = None

params.hash_algorithm = 'phash'
params.hash_size = 16

# %%
from utils import evaluate_MVTecAD

results = evaluate_MVTecAD(dataroot, img_hash.ImgHashAnoDet, params,
                test_targets=None
                )
# Out:
# Evaluating: ['bottle', 'cable', 'capsule', 'carpet', 'grid', 'hazelnut', 'leather', 'metal_nut', 'pill', 'screw', 'tile', 'toothbrush', 'transistor', 'wood', 'zipper']
#
# --- Start evaluating [bottle] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-bottle.pkl
#  evaluating...
# distance_threshold: 1.5883665888309175 # Threshold k-sigma [2.0]
# distance_threshold: 0.9003944773175543 # Threshold max FPR [0.1]
# distance_threshold: 0.4911242603550296 # Threshold min TPR [1.0]
# distance_norm_factor: 0.19088855421686746
# Results: {'target': ['bottle'], 'auc': [0.898809523809524], 'th_k_sigma': [1.5883665888309175], 'th_fpr': [0.9003944773175543], 'th_tpr': [0.4911242603550296], 'norm_factor': [0.19088855421686746], 'pauc': [0.8663324979114453]}
#
# --- Start evaluating [cable] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-cable.pkl
#  evaluating...
# distance_threshold: 1.2967507678353172 # Threshold k-sigma [2.0]
# distance_threshold: 1.1084624553039333 # Threshold max FPR [0.1]
# distance_threshold: 0.7151370679380215 # Threshold min TPR [1.0]
# distance_norm_factor: 0.21848958333333332
# Results: {'target': ['cable'], 'auc': [0.749531484257871], 'th_k_sigma': [1.2967507678353172], 'th_fpr': [1.1084624553039333], 'th_tpr': [0.7151370679380215], 'norm_factor': [0.21848958333333332], 'pauc': [0.5935847865540914]}
#
# --- Start evaluating [capsule] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-capsule.pkl
#  evaluating...
# distance_threshold: 1.8694879740974524 # Threshold k-sigma [2.0]
# distance_threshold: 1.256288239292998 # Threshold max FPR [0.1]
# distance_threshold: 0.35893949694085653 # Threshold min TPR [1.0]
# distance_norm_factor: 0.08706202651515152
# Results: {'target': ['capsule'], 'auc': [0.7269644994016754], 'th_k_sigma': [1.8694879740974524], 'th_fpr': [1.256288239292998], 'th_tpr': [0.35893949694085653], 'norm_factor': [0.08706202651515152], 'pauc': [0.5978523292675246]}
#
# --- Start evaluating [carpet] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-carpet.pkl
#  evaluating...
# distance_threshold: 1.0650151454479062 # Threshold k-sigma [2.0]
# distance_threshold: 1.060181227560267 # Threshold max FPR [0.1]
# distance_threshold: 0.9001538724568303 # Threshold min TPR [1.0]
# distance_norm_factor: 0.39055822649572647
# Results: {'target': ['carpet'], 'auc': [0.5072231139646869], 'th_k_sigma': [1.0650151454479062], 'th_fpr': [1.060181227560267], 'th_tpr': [0.9001538724568303], 'norm_factor': [0.39055822649572647], 'pauc': [0.5322294500295683]}
#
# --- Start evaluating [grid] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-grid.pkl
#  evaluating...
# distance_threshold: 1.2862997950704744 # Threshold k-sigma [2.0]
# distance_threshold: 1.037484885126965 # Threshold max FPR [0.1]
# distance_threshold: 0.8016928657799275 # Threshold min TPR [1.0]
# distance_norm_factor: 0.3313301282051282
# Results: {'target': ['grid'], 'auc': [0.9139515455304928], 'th_k_sigma': [1.2862997950704744], 'th_fpr': [1.037484885126965], 'th_tpr': [0.8016928657799275], 'norm_factor': [0.3313301282051282], 'pauc': [0.8527239150507848]}
#
# --- Start evaluating [hazelnut] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-hazelnut.pkl
#  evaluating...
# distance_threshold: 1.2955880857206687 # Threshold k-sigma [2.0]
# distance_threshold: 1.0932044050496912 # Threshold max FPR [0.1]
# distance_threshold: 0.7977437550362612 # Threshold min TPR [1.0]
# distance_norm_factor: 0.2644176136363636
# Results: {'target': ['hazelnut'], 'auc': [0.7830357142857143], 'th_k_sigma': [1.2955880857206687], 'th_fpr': [1.0932044050496912], 'th_tpr': [0.7977437550362612], 'norm_factor': [0.2644176136363636], 'pauc': [0.6174812030075187]}
#
# --- Start evaluating [leather] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-leather.pkl
#  evaluating...
# distance_threshold: 1.1377610178814548 # Threshold k-sigma [2.0]
# distance_threshold: 0.9967504703266632 # Threshold max FPR [0.1]
# distance_threshold: 0.8907131862493586 # Threshold min TPR [1.0]
# distance_norm_factor: 0.36838457661290325
# Results: {'target': ['leather'], 'auc': [0.921875], 'th_k_sigma': [1.1377610178814548], 'th_fpr': [0.9967504703266632], 'th_tpr': [0.8907131862493586], 'norm_factor': [0.36838457661290325], 'pauc': [0.8628933066361557]}
#
# --- Start evaluating [metal_nut] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-metal_nut.pkl
#  evaluating...
# distance_threshold: 1.680619524992529 # Threshold k-sigma [2.0]
# distance_threshold: 1.1043990086741016 # Threshold max FPR [0.1]
# distance_threshold: 0.5343866171003717 # Threshold min TPR [1.0]
# distance_norm_factor: 0.21929347826086956
# Results: {'target': ['metal_nut'], 'auc': [0.656891495601173], 'th_k_sigma': [1.680619524992529], 'th_fpr': [1.1043990086741016], 'th_tpr': [0.5343866171003717], 'norm_factor': [0.21929347826086956], 'pauc': [0.607552605854813]}
#
# --- Start evaluating [pill] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-pill.pkl
#  evaluating...
# distance_threshold: 1.2228475089774273 # Threshold k-sigma [2.0]
# distance_threshold: 1.1120551090700346 # Threshold max FPR [0.1]
# distance_threshold: 0.7669345579793341 # Threshold min TPR [1.0]
# distance_norm_factor: 0.20373315868263472
# Results: {'target': ['pill'], 'auc': [0.6404800872885978], 'th_k_sigma': [1.2228475089774273], 'th_fpr': [1.1120551090700346], 'th_tpr': [0.7669345579793341], 'norm_factor': [0.20373315868263472], 'pauc': [0.5564073850747983]}
#
# --- Start evaluating [screw] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-screw.pkl
#  evaluating...
# distance_threshold: 1.6901193408238404 # Threshold k-sigma [2.0]
# distance_threshold: 1.3737008585630366 # Threshold max FPR [0.1]
# distance_threshold: 0.43380027112516945 # Threshold min TPR [1.0]
# distance_norm_factor: 0.108056640625
# Results: {'target': ['screw'], 'auc': [0.5981758557081369], 'th_k_sigma': [1.6901193408238404], 'th_fpr': [1.3737008585630366], 'th_tpr': [0.43380027112516945], 'norm_factor': [0.108056640625], 'pauc': [0.5250536671664815]}
#
# --- Start evaluating [tile] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-tile.pkl
#  evaluating...
# distance_threshold: 1.3089182415034704 # Threshold k-sigma [2.0]
# distance_threshold: 1.098497780812564 # Threshold max FPR [0.1]
# distance_threshold: 0.1398088084670536 # Threshold min TPR [1.0]
# distance_norm_factor: 0.39115918803418803
# Results: {'target': ['tile'], 'auc': [0.43145743145743143], 'th_k_sigma': [1.3089182415034704], 'th_fpr': [1.098497780812564], 'th_tpr': [0.1398088084670536], 'norm_factor': [0.39115918803418803], 'pauc': [0.49310539606592235]}
#
# --- Start evaluating [toothbrush] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-toothbrush.pkl
#  evaluating...
# distance_threshold: 1.587799402769075 # Threshold k-sigma [2.0]
# distance_threshold: 0.8921568627450981 # Threshold max FPR [0.1]
# distance_threshold: 0.6176470588235294 # Threshold min TPR [1.0]
# distance_norm_factor: 0.11383928571428571
# Results: {'target': ['toothbrush'], 'auc': [0.9666666666666667], 'th_k_sigma': [1.587799402769075], 'th_fpr': [0.8921568627450981], 'th_tpr': [0.6176470588235294], 'norm_factor': [0.11383928571428571], 'pauc': [0.9526315789473685]}
#
# --- Start evaluating [transistor] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-transistor.pkl
#  evaluating...
# distance_threshold: 1.5954263268269975 # Threshold k-sigma [2.0]
# distance_threshold: 1.079734219269103 # Threshold max FPR [0.1]
# distance_threshold: 0.8305647840531563 # Threshold min TPR [1.0]
# distance_norm_factor: 0.188125
# Results: {'target': ['transistor'], 'auc': [0.9085416666666667], 'th_k_sigma': [1.5954263268269975], 'th_fpr': [1.079734219269103], 'th_tpr': [0.8305647840531563], 'norm_factor': [0.188125], 'pauc': [0.7616959064327485]}
#
# --- Start evaluating [wood] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-wood.pkl
#  evaluating...
# distance_threshold: 1.0606644036467985 # Threshold k-sigma [2.0]
# distance_threshold: 1.0556792873051224 # Threshold max FPR [0.1]
# distance_threshold: 0.9579312051472407 # Threshold min TPR [1.0]
# distance_norm_factor: 0.3996242088607595
# Results: {'target': ['wood'], 'auc': [0.5714912280701754], 'th_k_sigma': [1.0606644036467985], 'th_fpr': [1.0556792873051224], 'th_tpr': [0.9579312051472407], 'norm_factor': [0.3996242088607595], 'pauc': [0.5342105263157895]}
#
# --- Start evaluating [zipper] ----
#  preprocessing...
#  training...
#  using cached tmp/mvtecad_phash16/hashtable-zipper.pkl
#  evaluating...
# distance_threshold: 1.148515574743729 # Threshold k-sigma [2.0]
# distance_threshold: 1.0553159851301115 # Threshold max FPR [0.1]
# distance_threshold: 0.7185130111524164 # Threshold min TPR [1.0]
# distance_norm_factor: 0.34794081125827814
# Results: {'target': ['zipper'], 'auc': [0.7375262605042016], 'th_k_sigma': [1.148515574743729], 'th_fpr': [1.0553159851301115], 'th_tpr': [0.7185130111524164], 'norm_factor': [0.34794081125827814], 'pauc': [0.5940678903140204]}
# done.

# %%
results.to_csv(f'sample_{params.project}.csv')
results
# Out:
#         target       auc  th_k_sigma    th_fpr    th_tpr  norm_factor  \
# 0       bottle  0.898810    1.588367  0.900394  0.491124     0.190889
# 1        cable  0.749531    1.296751  1.108462  0.715137     0.218490
# 2      capsule  0.726964    1.869488  1.256288  0.358939     0.087062
# 3       carpet  0.507223    1.065015  1.060181  0.900154     0.390558
# 4         grid  0.913952    1.286300  1.037485  0.801693     0.331330
# 5     hazelnut  0.783036    1.295588  1.093204  0.797744     0.264418
# 6      leather  0.921875    1.137761  0.996750  0.890713     0.368385
# 7    metal_nut  0.656891    1.680620  1.104399  0.534387     0.219293
# 8         pill  0.640480    1.222848  1.112055  0.766935     0.203733
# 9        screw  0.598176    1.690119  1.373701  0.433800     0.108057
# 10        tile  0.431457    1.308918  1.098498  0.139809     0.391159
# 11  toothbrush  0.966667    1.587799  0.892157  0.617647     0.113839
# 12  transistor  0.908542    1.595426  1.079734  0.830565     0.188125
# 13        wood  0.571491    1.060664  1.055679  0.957931     0.399624
# 14      zipper  0.737526    1.148516  1.055316  0.718513     0.347941
#
#         pauc
# 0   0.866332
# 1   0.593585
# 2   0.597852
# 3   0.532229
# 4   0.852724
# 5   0.617481
# 6   0.862893
# 7   0.607553
# 8   0.556407
# 9   0.525054
# 10  0.493105
# 11  0.952632
# 12  0.761696
# 13  0.534211
# 14  0.594068

# %% [markdown]
# ## If you want to try one by one

# %%
from dlcliche.utils import (load_pkl, save_as_pkl_binary)
sys.path.append('..')
from base_ano_det import BaseAnoDet


test_target = 'transistor'
folder = Path(dataroot)/test_target
good_files = sorted(folder.glob(f'train/good/*{params.suffix}'))
test_files = sorted(folder.glob(f'test/*/*{params.suffix}'))
test_y_trues = [f.parent.name != 'good' for f in test_files]

params.norm_factor = 0.188125 # from test result

det = img_hash.ImgHashAnoDet(params)
det.prepare_experiment()
# no need: det.setup_train(good_files)
det.train_model(good_files)

scores = det.predict(test_files)
norm_scores = det.normalize_score(scores)
print(norm_scores)
# Out:
#  using cached tmp/mvtecad_phash16/hashtable-None.pkl
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-49ebc34dcbfe> in <module>
#      18
#      19 scores = det.predict(test_files)
# ---> 20 norm_scores = det.normalize_score(scores)
#      21 print(norm_scores)
#
# ~/lab/p1/image-anomaly-det/base_ano_det.py in normalize_score(self, scores)
#      84     def normalize_score(self, scores):
#      85         if 'distance_norm_factor' not in self.params:
# ---> 86             raise ValueError(f'Set params.distance_norm_factor to normalize score.')
#      87         return scores / self.params.distance_norm_factor
#      88
#
# ValueError: Set params.distance_norm_factor to normalize score.
